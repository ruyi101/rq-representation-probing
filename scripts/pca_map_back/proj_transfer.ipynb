# %%
import json
from pathlib import Path
from collections import defaultdict

import torch
import pandas as pd


metric = "logistic"
synthetic = False


# ------------------------
# Config
# ------------------------

if synthetic:
    dm_jsonl = Path(f"pca_64/synthetic_{metric}_by_layer.jsonl")
    emb_dir = Path("../embeddings_synthetic")              # embeddings on OTHER datasets
    proj_dir = Path("projection_within_synthetic")
    proj_dir.mkdir(exist_ok=True)
else:
    dm_jsonl = Path(f"pca_64/{metric}_by_layer.jsonl")
    emb_dir = Path("../embeddings")                   # embeddings on OTHER datasets
    proj_dir = Path("projection_within_real")
    proj_dir.mkdir(exist_ok=True)

# ------------------------
# Load diffmean per layer
# ------------------------

records = []
with dm_jsonl.open("r") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        records.append(json.loads(line))

# dm_map: model_short -> list of entries
# each entry: {
#    "primary_benchmark": <benchmark where diffmean was trained>,
#    "primary_column": <column used to compute diffmean>,
#    "diffmean": tensor [L, D],
# }
dm_map = defaultdict(list)

for r in records:
    model_full = r["model"]          # e.g. "meta-llama/Llama-3-8B"
    model_short = model_full.split("/")[-1]
    primary_benchmark = r["benchmark"]   # source / training benchmark
    primary_column = r["column"]         # column used for diffmean
    diffmean = torch.tensor(r["vecs_back"], dtype=torch.float32)  # [L, D]

    entry = {
        "primary_benchmark": primary_benchmark,
        "primary_column": primary_column,
        "diffmean": diffmean,
    }
    dm_map[model_short].append(entry)

print(f"Loaded {len(records)} diffmean entries across "
      f"{len(dm_map)} models from {dm_jsonl}")

# ------------------------
# Iterate over embedding files
# ------------------------

pt_files = sorted(emb_dir.glob("*.pt"))
print(f"Found {len(pt_files)} embedding files in {emb_dir}")

for path in pt_files:
    print(f"\n=== Processing {path} ===")
    data = torch.load(path, map_location="cpu")

    emb_all = data["embeddings"]          # [N_total, L, D]
    model_name = data["model_name"]       # full HF name
    benchmark = data["benchmark"]         # TARGET benchmark (eval)
    column = data["column"]               # column from *embeddings*
    model_short = model_name.split("/")[-1]

    # load the full CSV for this TARGET benchmark
    csv_path = f"../{benchmark}.csv"
    df = pd.read_csv(csv_path)

    print(f"target_benchmark={benchmark}, column={column}, model={model_name}")
    print(f"embeddings shape: {emb_all.shape}, df rows: {len(df)}")

    if model_short not in dm_map:
        print(f"  -> No diffmean entries for model {model_short}, skipping.")
        continue

    # Use id to align DF rows with embedding rows
    ids = df["id"].to_numpy()
    labels = df["binary_label"].to_numpy()
    datasets = df["dataset"].tolist()     # list of split names per row

    ids_t = torch.as_tensor(ids, dtype=torch.long)
    assert ids_t.max().item() < emb_all.shape[0], (
        f"Max id {ids_t.max().item()} >= num embeddings {emb_all.shape[0]}"
    )

    # X: [num_rows, L, D]
    X = emb_all[ids_t]
    num_rows, num_layers, embed_dim = X.shape

    print(f"aligned num_rows={num_rows}, num_layers={num_layers}, embed_dim={embed_dim}")

    eps = 1e-8

    # --------- KEY CHANGE: only match on model_short, not column ----------
    # For this model, project onto *all* diffmean vectors (each from a possibly
    # different primary_benchmark / primary_column).
    for e in dm_map[model_short]:
        primary_benchmark = e["primary_benchmark"]   # where diffmean was trained
        primary_column = e["primary_column"]         # column used for diffmean
        diffmean = e["diffmean"]     
        
        if benchmark == primary_benchmark and column == primary_column:
            print(
                f"  -> Skipping projection from primary_benchmark={primary_benchmark}, "
                f"primary_column={primary_column} to itself."
            )
            continue

        assert diffmean.shape == (num_layers, embed_dim), (
            f"Shape mismatch for primary_benchmark={primary_benchmark}, "
            f"primary_column={primary_column}: "
            f"X {X.shape}, diffmean {diffmean.shape}"
        )

        # Normalize ONLY the diffmean vectors: d_hat_l = d_l / ||d_l||
        dm_unit = diffmean / (diffmean.norm(dim=-1, keepdim=True) + eps)  # [L, D]

        # Projection: x_{i,l} ⋅ d_hat_l
        # ( [num_rows,L,D] * [1,L,D] ) -> [num_rows,L,D] -> sum over D -> [num_rows,L]
        proj = (X * dm_unit.unsqueeze(0)).sum(dim=-1)   # [num_rows, L]

        print(
            f"  -> primary_benchmark={primary_benchmark}, "
            f"primary_column={primary_column}, projection shape: {proj.shape}"
        )

        out = {
            "projection": proj,                           # [num_rows, L]
            "id": torch.as_tensor(ids, dtype=torch.long),
            "binary_label": torch.as_tensor(labels),      # same order as rows in df
            "dataset": datasets,                          # list of split names per row
            "benchmark": benchmark,                       # TARGET benchmark (eval)
            "column": column,                             # COLUMN OF EMBEDDINGS (target)
            "primary_benchmark": primary_benchmark,       # SOURCE benchmark (train)
            "primary_column": primary_column,             # SOURCE column (optional)
            "model_name": model_name,
            "metric": metric,
        }

        # Make filename explicit: primary->target
        out_name = (
            f"{primary_benchmark}_TO_{benchmark}_{column}_{primary_column}_"
            f"{model_short}_{metric}.pt"
        )
        out_path = proj_dir / out_name
        torch.save(out, out_path)
        print(f"  -> Saved projections to {out_path}")
# Out:
# Loaded 25 diffmean entries across 5 models from pca_64/logistic_by_layer.jsonl
# Found 30 embedding files in ../embeddings
#
# === Processing ../embeddings/RQ_question_Llama-3.1-8B-Instruct.pt ===
# target_benchmark=RQ, column=question, model=meta-llama/Llama-3.1-8B-Instruct
# embeddings shape: torch.Size([4997, 33, 4096]), df rows: 4997
# aligned num_rows=4997, num_layers=33, embed_dim=4096
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([4997, 33])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_paragraph_Llama-3.1-8B-Instruct_logistic.pt
#   -> Skipping projection from primary_benchmark=RQ, primary_column=question to itself.
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([4997, 33])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_longer_context_Llama-3.1-8B-Instruct_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([4997, 33])
#   -> Saved projections to projection_within_real/RQ_TO_RQ_question_question_with_context_Llama-3.1-8B-Instruct_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([4997, 33])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_full_turn_Llama-3.1-8B-Instruct_logistic.pt
#
# === Processing ../embeddings/RQ_question_Llama-3.3-70B-Instruct.pt ===
# target_benchmark=RQ, column=question, model=meta-llama/Llama-3.3-70B-Instruct
# embeddings shape: torch.Size([4997, 81, 8192]), df rows: 4997
# aligned num_rows=4997, num_layers=81, embed_dim=8192
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([4997, 81])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_paragraph_Llama-3.3-70B-Instruct_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([4997, 81])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_full_turn_Llama-3.3-70B-Instruct_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([4997, 81])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_longer_context_Llama-3.3-70B-Instruct_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([4997, 81])
#   -> Saved projections to projection_within_real/RQ_TO_RQ_question_question_with_context_Llama-3.3-70B-Instruct_logistic.pt
#   -> Skipping projection from primary_benchmark=RQ, primary_column=question to itself.
#
# === Processing ../embeddings/RQ_question_Qwen3-30B-A3B-Instruct-2507.pt ===
# target_benchmark=RQ, column=question, model=Qwen/Qwen3-30B-A3B-Instruct-2507
# embeddings shape: torch.Size([4997, 49, 2048]), df rows: 4997
#   -> No diffmean entries for model Qwen3-30B-A3B-Instruct-2507, skipping.
#
# === Processing ../embeddings/RQ_question_Qwen3-32B.pt ===
# target_benchmark=RQ, column=question, model=Qwen/Qwen3-32B
# embeddings shape: torch.Size([4997, 65, 5120]), df rows: 4997
# aligned num_rows=4997, num_layers=65, embed_dim=5120
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([4997, 65])
#   -> Saved projections to projection_within_real/RQ_TO_RQ_question_question_with_context_Qwen3-32B_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([4997, 65])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_full_turn_Qwen3-32B_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([4997, 65])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_longer_context_Qwen3-32B_logistic.pt
#   -> Skipping projection from primary_benchmark=RQ, primary_column=question to itself.
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([4997, 65])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_paragraph_Qwen3-32B_logistic.pt
#
# === Processing ../embeddings/RQ_question_Qwen3-8B.pt ===
# target_benchmark=RQ, column=question, model=Qwen/Qwen3-8B
# embeddings shape: torch.Size([4997, 37, 4096]), df rows: 4997
# aligned num_rows=4997, num_layers=37, embed_dim=4096
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([4997, 37])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_paragraph_Qwen3-8B_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([4997, 37])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_longer_context_Qwen3-8B_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([4997, 37])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_full_turn_Qwen3-8B_logistic.pt
#   -> Skipping projection from primary_benchmark=RQ, primary_column=question to itself.
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([4997, 37])
#   -> Saved projections to projection_within_real/RQ_TO_RQ_question_question_with_context_Qwen3-8B_logistic.pt
#
# === Processing ../embeddings/RQ_question_gpt-oss-20b.pt ===
# target_benchmark=RQ, column=question, model=openai/gpt-oss-20b
# embeddings shape: torch.Size([4997, 25, 2880]), df rows: 4997
# aligned num_rows=4997, num_layers=25, embed_dim=2880
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([4997, 25])
#   -> Saved projections to projection_within_real/RQ_TO_RQ_question_question_with_context_gpt-oss-20b_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([4997, 25])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_full_turn_gpt-oss-20b_logistic.pt
#   -> Skipping projection from primary_benchmark=RQ, primary_column=question to itself.
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([4997, 25])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_longer_context_gpt-oss-20b_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([4997, 25])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_paragraph_gpt-oss-20b_logistic.pt
#
# === Processing ../embeddings/RQ_question_with_context_Llama-3.1-8B-Instruct.pt ===
# target_benchmark=RQ, column=question_with_context, model=meta-llama/Llama-3.1-8B-Instruct
# embeddings shape: torch.Size([4997, 33, 4096]), df rows: 4997
# aligned num_rows=4997, num_layers=33, embed_dim=4096
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([4997, 33])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_Llama-3.1-8B-Instruct_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([4997, 33])
#   -> Saved projections to projection_within_real/RQ_TO_RQ_question_with_context_question_Llama-3.1-8B-Instruct_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([4997, 33])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_Llama-3.1-8B-Instruct_logistic.pt
#   -> Skipping projection from primary_benchmark=RQ, primary_column=question_with_context to itself.
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([4997, 33])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_Llama-3.1-8B-Instruct_logistic.pt
#
# === Processing ../embeddings/RQ_question_with_context_Llama-3.3-70B-Instruct.pt ===
# target_benchmark=RQ, column=question_with_context, model=meta-llama/Llama-3.3-70B-Instruct
# embeddings shape: torch.Size([4997, 81, 8192]), df rows: 4997
# aligned num_rows=4997, num_layers=81, embed_dim=8192
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([4997, 81])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_Llama-3.3-70B-Instruct_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([4997, 81])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_Llama-3.3-70B-Instruct_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([4997, 81])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_Llama-3.3-70B-Instruct_logistic.pt
#   -> Skipping projection from primary_benchmark=RQ, primary_column=question_with_context to itself.
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([4997, 81])
#   -> Saved projections to projection_within_real/RQ_TO_RQ_question_with_context_question_Llama-3.3-70B-Instruct_logistic.pt
#
# === Processing ../embeddings/RQ_question_with_context_Qwen3-30B-A3B-Instruct-2507.pt ===
# target_benchmark=RQ, column=question_with_context, model=Qwen/Qwen3-30B-A3B-Instruct-2507
# embeddings shape: torch.Size([4997, 49, 2048]), df rows: 4997
#   -> No diffmean entries for model Qwen3-30B-A3B-Instruct-2507, skipping.
#
# === Processing ../embeddings/RQ_question_with_context_Qwen3-32B.pt ===
# target_benchmark=RQ, column=question_with_context, model=Qwen/Qwen3-32B
# embeddings shape: torch.Size([4997, 65, 5120]), df rows: 4997
# aligned num_rows=4997, num_layers=65, embed_dim=5120
#   -> Skipping projection from primary_benchmark=RQ, primary_column=question_with_context to itself.
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([4997, 65])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_Qwen3-32B_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([4997, 65])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_Qwen3-32B_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([4997, 65])
#   -> Saved projections to projection_within_real/RQ_TO_RQ_question_with_context_question_Qwen3-32B_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([4997, 65])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_Qwen3-32B_logistic.pt
#
# === Processing ../embeddings/RQ_question_with_context_Qwen3-8B.pt ===
# target_benchmark=RQ, column=question_with_context, model=Qwen/Qwen3-8B
# embeddings shape: torch.Size([4997, 37, 4096]), df rows: 4997
# aligned num_rows=4997, num_layers=37, embed_dim=4096
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([4997, 37])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_Qwen3-8B_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([4997, 37])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_Qwen3-8B_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([4997, 37])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_Qwen3-8B_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([4997, 37])
#   -> Saved projections to projection_within_real/RQ_TO_RQ_question_with_context_question_Qwen3-8B_logistic.pt
#   -> Skipping projection from primary_benchmark=RQ, primary_column=question_with_context to itself.
#
# === Processing ../embeddings/RQ_question_with_context_gpt-oss-20b.pt ===
# target_benchmark=RQ, column=question_with_context, model=openai/gpt-oss-20b
# embeddings shape: torch.Size([4997, 25, 2880]), df rows: 4997
# aligned num_rows=4997, num_layers=25, embed_dim=2880
#   -> Skipping projection from primary_benchmark=RQ, primary_column=question_with_context to itself.
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([4997, 25])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_gpt-oss-20b_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([4997, 25])
#   -> Saved projections to projection_within_real/RQ_TO_RQ_question_with_context_question_gpt-oss-20b_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([4997, 25])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_gpt-oss-20b_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([4997, 25])
#   -> Saved projections to projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_gpt-oss-20b_logistic.pt
#
# === Processing ../embeddings/SRAQ_full_turn_Llama-3.1-8B-Instruct.pt ===
# target_benchmark=SRAQ, column=full_turn, model=meta-llama/Llama-3.1-8B-Instruct
# embeddings shape: torch.Size([971, 33, 4096]), df rows: 971
# aligned num_rows=971, num_layers=33, embed_dim=4096
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([971, 33])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_Llama-3.1-8B-Instruct_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([971, 33])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_full_turn_question_Llama-3.1-8B-Instruct_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([971, 33])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_Llama-3.1-8B-Instruct_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([971, 33])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_Llama-3.1-8B-Instruct_logistic.pt
#   -> Skipping projection from primary_benchmark=SRAQ, primary_column=full_turn to itself.
#
# === Processing ../embeddings/SRAQ_full_turn_Llama-3.3-70B-Instruct.pt ===
# target_benchmark=SRAQ, column=full_turn, model=meta-llama/Llama-3.3-70B-Instruct
# embeddings shape: torch.Size([971, 81, 8192]), df rows: 971
# aligned num_rows=971, num_layers=81, embed_dim=8192
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([971, 81])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_Llama-3.3-70B-Instruct_logistic.pt
#   -> Skipping projection from primary_benchmark=SRAQ, primary_column=full_turn to itself.
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([971, 81])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_Llama-3.3-70B-Instruct_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([971, 81])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_Llama-3.3-70B-Instruct_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([971, 81])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_full_turn_question_Llama-3.3-70B-Instruct_logistic.pt
#
# === Processing ../embeddings/SRAQ_full_turn_Qwen3-30B-A3B-Instruct-2507.pt ===
# target_benchmark=SRAQ, column=full_turn, model=Qwen/Qwen3-30B-A3B-Instruct-2507
# embeddings shape: torch.Size([971, 49, 2048]), df rows: 971
#   -> No diffmean entries for model Qwen3-30B-A3B-Instruct-2507, skipping.
#
# === Processing ../embeddings/SRAQ_full_turn_Qwen3-32B.pt ===
# target_benchmark=SRAQ, column=full_turn, model=Qwen/Qwen3-32B
# embeddings shape: torch.Size([971, 65, 5120]), df rows: 971
# aligned num_rows=971, num_layers=65, embed_dim=5120
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([971, 65])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_Qwen3-32B_logistic.pt
#   -> Skipping projection from primary_benchmark=SRAQ, primary_column=full_turn to itself.
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([971, 65])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_Qwen3-32B_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([971, 65])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_full_turn_question_Qwen3-32B_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([971, 65])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_Qwen3-32B_logistic.pt
#
# === Processing ../embeddings/SRAQ_full_turn_Qwen3-8B.pt ===
# target_benchmark=SRAQ, column=full_turn, model=Qwen/Qwen3-8B
# embeddings shape: torch.Size([971, 37, 4096]), df rows: 971
# aligned num_rows=971, num_layers=37, embed_dim=4096
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([971, 37])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_Qwen3-8B_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([971, 37])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_Qwen3-8B_logistic.pt
#   -> Skipping projection from primary_benchmark=SRAQ, primary_column=full_turn to itself.
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([971, 37])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_full_turn_question_Qwen3-8B_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([971, 37])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_Qwen3-8B_logistic.pt
#
# === Processing ../embeddings/SRAQ_full_turn_gpt-oss-20b.pt ===
# target_benchmark=SRAQ, column=full_turn, model=openai/gpt-oss-20b
# embeddings shape: torch.Size([971, 25, 2880]), df rows: 971
# aligned num_rows=971, num_layers=25, embed_dim=2880
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([971, 25])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_gpt-oss-20b_logistic.pt
#   -> Skipping projection from primary_benchmark=SRAQ, primary_column=full_turn to itself.
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([971, 25])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_full_turn_question_gpt-oss-20b_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([971, 25])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_gpt-oss-20b_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([971, 25])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_gpt-oss-20b_logistic.pt
#
# === Processing ../embeddings/SRAQ_longer_context_Llama-3.1-8B-Instruct.pt ===
# target_benchmark=SRAQ, column=longer_context, model=meta-llama/Llama-3.1-8B-Instruct
# embeddings shape: torch.Size([971, 33, 4096]), df rows: 971
# aligned num_rows=971, num_layers=33, embed_dim=4096
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([971, 33])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_Llama-3.1-8B-Instruct_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([971, 33])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_longer_context_question_Llama-3.1-8B-Instruct_logistic.pt
#   -> Skipping projection from primary_benchmark=SRAQ, primary_column=longer_context to itself.
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([971, 33])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_Llama-3.1-8B-Instruct_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([971, 33])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_Llama-3.1-8B-Instruct_logistic.pt
#
# === Processing ../embeddings/SRAQ_longer_context_Llama-3.3-70B-Instruct.pt ===
# target_benchmark=SRAQ, column=longer_context, model=meta-llama/Llama-3.3-70B-Instruct
# embeddings shape: torch.Size([971, 81, 8192]), df rows: 971
# aligned num_rows=971, num_layers=81, embed_dim=8192
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([971, 81])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_Llama-3.3-70B-Instruct_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([971, 81])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_Llama-3.3-70B-Instruct_logistic.pt
#   -> Skipping projection from primary_benchmark=SRAQ, primary_column=longer_context to itself.
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([971, 81])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_Llama-3.3-70B-Instruct_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([971, 81])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_longer_context_question_Llama-3.3-70B-Instruct_logistic.pt
#
# === Processing ../embeddings/SRAQ_longer_context_Qwen3-30B-A3B-Instruct-2507.pt ===
# target_benchmark=SRAQ, column=longer_context, model=Qwen/Qwen3-30B-A3B-Instruct-2507
# embeddings shape: torch.Size([971, 49, 2048]), df rows: 971
#   -> No diffmean entries for model Qwen3-30B-A3B-Instruct-2507, skipping.
#
# === Processing ../embeddings/SRAQ_longer_context_Qwen3-32B.pt ===
# target_benchmark=SRAQ, column=longer_context, model=Qwen/Qwen3-32B
# embeddings shape: torch.Size([971, 65, 5120]), df rows: 971
# aligned num_rows=971, num_layers=65, embed_dim=5120
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([971, 65])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_Qwen3-32B_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([971, 65])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_Qwen3-32B_logistic.pt
#   -> Skipping projection from primary_benchmark=SRAQ, primary_column=longer_context to itself.
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([971, 65])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_longer_context_question_Qwen3-32B_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([971, 65])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_Qwen3-32B_logistic.pt
#
# === Processing ../embeddings/SRAQ_longer_context_Qwen3-8B.pt ===
# target_benchmark=SRAQ, column=longer_context, model=Qwen/Qwen3-8B
# embeddings shape: torch.Size([971, 37, 4096]), df rows: 971
# aligned num_rows=971, num_layers=37, embed_dim=4096
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([971, 37])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_Qwen3-8B_logistic.pt
#   -> Skipping projection from primary_benchmark=SRAQ, primary_column=longer_context to itself.
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([971, 37])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_Qwen3-8B_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([971, 37])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_longer_context_question_Qwen3-8B_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([971, 37])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_Qwen3-8B_logistic.pt
#
# === Processing ../embeddings/SRAQ_longer_context_gpt-oss-20b.pt ===
# target_benchmark=SRAQ, column=longer_context, model=openai/gpt-oss-20b
# embeddings shape: torch.Size([971, 25, 2880]), df rows: 971
# aligned num_rows=971, num_layers=25, embed_dim=2880
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([971, 25])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_gpt-oss-20b_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([971, 25])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_gpt-oss-20b_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([971, 25])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_longer_context_question_gpt-oss-20b_logistic.pt
#   -> Skipping projection from primary_benchmark=SRAQ, primary_column=longer_context to itself.
#   -> primary_benchmark=SRAQ, primary_column=paragraph, projection shape: torch.Size([971, 25])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_gpt-oss-20b_logistic.pt
#
# === Processing ../embeddings/SRAQ_paragraph_Llama-3.1-8B-Instruct.pt ===
# target_benchmark=SRAQ, column=paragraph, model=meta-llama/Llama-3.1-8B-Instruct
# embeddings shape: torch.Size([971, 33, 4096]), df rows: 971
# aligned num_rows=971, num_layers=33, embed_dim=4096
#   -> Skipping projection from primary_benchmark=SRAQ, primary_column=paragraph to itself.
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([971, 33])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_paragraph_question_Llama-3.1-8B-Instruct_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([971, 33])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_Llama-3.1-8B-Instruct_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([971, 33])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_Llama-3.1-8B-Instruct_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([971, 33])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_Llama-3.1-8B-Instruct_logistic.pt
#
# === Processing ../embeddings/SRAQ_paragraph_Llama-3.3-70B-Instruct.pt ===
# target_benchmark=SRAQ, column=paragraph, model=meta-llama/Llama-3.3-70B-Instruct
# embeddings shape: torch.Size([971, 81, 8192]), df rows: 971
# aligned num_rows=971, num_layers=81, embed_dim=8192
#   -> Skipping projection from primary_benchmark=SRAQ, primary_column=paragraph to itself.
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([971, 81])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_Llama-3.3-70B-Instruct_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([971, 81])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_Llama-3.3-70B-Instruct_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([971, 81])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_Llama-3.3-70B-Instruct_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([971, 81])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_paragraph_question_Llama-3.3-70B-Instruct_logistic.pt
#
# === Processing ../embeddings/SRAQ_paragraph_Qwen3-30B-A3B-Instruct-2507.pt ===
# target_benchmark=SRAQ, column=paragraph, model=Qwen/Qwen3-30B-A3B-Instruct-2507
# embeddings shape: torch.Size([971, 49, 2048]), df rows: 971
#   -> No diffmean entries for model Qwen3-30B-A3B-Instruct-2507, skipping.
#
# === Processing ../embeddings/SRAQ_paragraph_Qwen3-32B.pt ===
# target_benchmark=SRAQ, column=paragraph, model=Qwen/Qwen3-32B
# embeddings shape: torch.Size([971, 65, 5120]), df rows: 971
# aligned num_rows=971, num_layers=65, embed_dim=5120
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([971, 65])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_Qwen3-32B_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([971, 65])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_Qwen3-32B_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([971, 65])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_Qwen3-32B_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([971, 65])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_paragraph_question_Qwen3-32B_logistic.pt
#   -> Skipping projection from primary_benchmark=SRAQ, primary_column=paragraph to itself.
#
# === Processing ../embeddings/SRAQ_paragraph_Qwen3-8B.pt ===
# target_benchmark=SRAQ, column=paragraph, model=Qwen/Qwen3-8B
# embeddings shape: torch.Size([971, 37, 4096]), df rows: 971
# aligned num_rows=971, num_layers=37, embed_dim=4096
#   -> Skipping projection from primary_benchmark=SRAQ, primary_column=paragraph to itself.
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([971, 37])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_Qwen3-8B_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([971, 37])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_Qwen3-8B_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([971, 37])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_paragraph_question_Qwen3-8B_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([971, 37])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_Qwen3-8B_logistic.pt
#
# === Processing ../embeddings/SRAQ_paragraph_gpt-oss-20b.pt ===
# target_benchmark=SRAQ, column=paragraph, model=openai/gpt-oss-20b
# embeddings shape: torch.Size([971, 25, 2880]), df rows: 971
# aligned num_rows=971, num_layers=25, embed_dim=2880
#   -> primary_benchmark=RQ, primary_column=question_with_context, projection shape: torch.Size([971, 25])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_gpt-oss-20b_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=full_turn, projection shape: torch.Size([971, 25])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_gpt-oss-20b_logistic.pt
#   -> primary_benchmark=RQ, primary_column=question, projection shape: torch.Size([971, 25])
#   -> Saved projections to projection_within_real/RQ_TO_SRAQ_paragraph_question_gpt-oss-20b_logistic.pt
#   -> primary_benchmark=SRAQ, primary_column=longer_context, projection shape: torch.Size([971, 25])
#   -> Saved projections to projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_gpt-oss-20b_logistic.pt
#   -> Skipping projection from primary_benchmark=SRAQ, primary_column=paragraph to itself.

# %%
import json
from pathlib import Path

import numpy as np
import torch
from sklearn.metrics import roc_auc_score  # make sure scikit-learn is installed

def auc_confint_hanley_mcneil(y_true, y_score, alpha=0.05):
    """
    y_true: 0/1 labels
    y_score: continuous scores
    Returns: auc, lower, upper  (95% CI by default)
    """
    auc = roc_auc_score(y_true, y_score)

    y_true = np.asarray(y_true)
    n_pos = (y_true == 1).sum()
    n_neg = (y_true == 0).sum()

    Q1 = auc / (2.0 - auc)
    Q2 = 2.0 * auc**2 / (1.0 + auc)

    var_auc = (
        auc * (1.0 - auc)
        + (n_pos - 1.0) * (Q1 - auc**2)
        + (n_neg - 1.0) * (Q2 - auc**2)
    ) / (n_pos * n_neg)

    se = np.sqrt(var_auc)
    z = 1.96  # for 95% CI

    lower = auc - z * se
    upper = auc + z * se

    # clamp to [0,1]
    lower = max(0.0, lower)
    upper = min(1.0, upper)

    return float(auc), float(lower), float(upper)

# %%
synthetic = False


if synthetic:
    proj_dir = Path("projection_within_synthetic")
    out_path = Path("auroc_project_within_synthetic.jsonl")
else:
    proj_dir = Path("projection_within_real")
    out_path = Path("auroc_project_within_real.jsonl")

pt_files = sorted(proj_dir.glob("*.pt"))
print(f"Found {len(pt_files)} projection files in {proj_dir}")

with open(out_path, "w", encoding="utf-8") as out_f:
    for path in pt_files:
        print(f"\n=== Processing {path} ===")
        data = torch.load(path, map_location="cpu")

        proj = data["projection"]            # [N, L]
        labels = data["binary_label"]        # tensor [N]
        datasets = data["dataset"]           # list of length N
        benchmark = data["benchmark"]
        column = data["column"]
        primary_benchmark = data["primary_benchmark"]
        primary_column = data["primary_column"]
        model_name = data["model_name"]
        metric = data["metric"]
        model_short = model_name.split("/")[-1]

        proj_np = proj.numpy()               # [N, L]
        y_np = labels.numpy()                # [N]

        N, num_layers = proj_np.shape
        print(f"N={N}, num_layers={num_layers}")

        # preserve split order as they first appear in datasets
        seen = set()
        splits = []
        for s in datasets:
            if s not in seen:
                seen.add(s)
                splits.append(s)

        record = {
            "benchmark": benchmark,
            "column": column,
            "model": model_short,
            "primary_benchmark": primary_benchmark,
            "primary_column" : primary_column,
            "metric": metric,         
        }

        # test_split = "test"
        # print(f"Computing AUROC on split '{test_split}'")
        # indices = [i for i, s in enumerate(datasets) if s == test_split]
        # y_split = y_np[indices]
        # X_split = proj_np[indices]        # [n_split, L]
        y_split = y_np
        X_split = proj_np        # [n_split, L]

        aurocs = []
        aurocs_ci = []
        for layer_idx in range(num_layers):
            scores = X_split[:, layer_idx]
            try:
                auc, lo, hi = auc_confint_hanley_mcneil(y_split, scores)
            except ValueError:
                # happens if y_split is all 0s or all 1s
                auc, lo, hi = None, None, None
            aurocs.append(auc)
            aurocs_ci.append([lo, hi])

        # e.g. record["train"] = [auroc_layer0, ...]
        #      record["train_ci"] = [[lo0, hi0], [lo1, hi1], ...]
        record['auroc'] = aurocs
        record['auroc_ci'] = aurocs_ci

        out_f.write(json.dumps(record) + "\n")
        out_f.flush()
        print(f"Wrote AUROC record for {benchmark}/{column} ({model_short})")

print(f"\nAll done. AUROCs saved to {out_path}")
# Out:
# Found 322 projection files in projection_within_real
#
# === Processing projection_within_real/RQ_TO_RQ_question_question_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_RQ_question_question_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_RQ_question_question_with_context_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_RQ_question_question_with_context_Llama-3.1-8B-Instruct_hinge.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_RQ_question_question_with_context_Llama-3.1-8B-Instruct_logistic.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_RQ_question_question_with_context_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_RQ_question_question_with_context_Llama-3.3-70B-Instruct_hinge.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_RQ_question_question_with_context_Llama-3.3-70B-Instruct_logistic.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_RQ_question_question_with_context_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=4997, num_layers=49
# Wrote AUROC record for RQ/question (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/RQ_TO_RQ_question_question_with_context_Qwen3-32B_diffmean.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_RQ_question_question_with_context_Qwen3-32B_hinge.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_RQ_question_question_with_context_Qwen3-32B_logistic.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_RQ_question_question_with_context_Qwen3-8B_diffmean.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_RQ_question_question_with_context_Qwen3-8B_hinge.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_RQ_question_question_with_context_Qwen3-8B_logistic.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_RQ_question_question_with_context_gpt-oss-20b_diffmean.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_RQ_question_question_with_context_gpt-oss-20b_hinge.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_RQ_question_question_with_context_gpt-oss-20b_logistic.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_RQ_question_with_context_question_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question_with_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_RQ_question_with_context_question_Llama-3.1-8B-Instruct_hinge.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question_with_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_RQ_question_with_context_question_Llama-3.1-8B-Instruct_logistic.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question_with_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_RQ_question_with_context_question_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question_with_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_RQ_question_with_context_question_Llama-3.3-70B-Instruct_hinge.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question_with_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_RQ_question_with_context_question_Llama-3.3-70B-Instruct_logistic.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question_with_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_RQ_question_with_context_question_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=4997, num_layers=49
# Wrote AUROC record for RQ/question_with_context (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/RQ_TO_RQ_question_with_context_question_Qwen3-32B_diffmean.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question_with_context (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_RQ_question_with_context_question_Qwen3-32B_hinge.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question_with_context (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_RQ_question_with_context_question_Qwen3-32B_logistic.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question_with_context (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_RQ_question_with_context_question_Qwen3-8B_diffmean.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question_with_context (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_RQ_question_with_context_question_Qwen3-8B_hinge.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question_with_context (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_RQ_question_with_context_question_Qwen3-8B_logistic.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question_with_context (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_RQ_question_with_context_question_gpt-oss-20b_diffmean.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question_with_context (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_RQ_question_with_context_question_gpt-oss-20b_hinge.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question_with_context (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_RQ_question_with_context_question_gpt-oss-20b_logistic.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question_with_context (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/full_turn (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_Llama-3.1-8B-Instruct_hinge.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/full_turn (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_Llama-3.1-8B-Instruct_logistic.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/full_turn (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/full_turn (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_Llama-3.3-70B-Instruct_hinge.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/full_turn (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_Llama-3.3-70B-Instruct_logistic.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/full_turn (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=971, num_layers=49
# Wrote AUROC record for SRAQ/full_turn (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_Qwen3-32B_diffmean.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/full_turn (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_Qwen3-32B_hinge.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/full_turn (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_Qwen3-32B_logistic.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/full_turn (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_Qwen3-8B_diffmean.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/full_turn (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_Qwen3-8B_hinge.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/full_turn (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_Qwen3-8B_logistic.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/full_turn (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_gpt-oss-20b_diffmean.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/full_turn (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_gpt-oss-20b_hinge.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/full_turn (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_gpt-oss-20b_logistic.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/full_turn (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/full_turn (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_Llama-3.1-8B-Instruct_hinge.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/full_turn (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_Llama-3.1-8B-Instruct_logistic.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/full_turn (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/full_turn (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_Llama-3.3-70B-Instruct_hinge.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/full_turn (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_Llama-3.3-70B-Instruct_logistic.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/full_turn (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=971, num_layers=49
# Wrote AUROC record for SRAQ/full_turn (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_Qwen3-32B_diffmean.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/full_turn (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_Qwen3-32B_hinge.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/full_turn (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_Qwen3-32B_logistic.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/full_turn (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_Qwen3-8B_diffmean.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/full_turn (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_Qwen3-8B_hinge.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/full_turn (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_Qwen3-8B_logistic.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/full_turn (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_gpt-oss-20b_diffmean.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/full_turn (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_gpt-oss-20b_hinge.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/full_turn (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_SRAQ_full_turn_question_with_context_gpt-oss-20b_logistic.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/full_turn (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/longer_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_Llama-3.1-8B-Instruct_hinge.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/longer_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_Llama-3.1-8B-Instruct_logistic.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/longer_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/longer_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_Llama-3.3-70B-Instruct_hinge.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/longer_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_Llama-3.3-70B-Instruct_logistic.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/longer_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=971, num_layers=49
# Wrote AUROC record for SRAQ/longer_context (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_Qwen3-32B_diffmean.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/longer_context (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_Qwen3-32B_hinge.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/longer_context (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_Qwen3-32B_logistic.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/longer_context (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_Qwen3-8B_diffmean.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/longer_context (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_Qwen3-8B_hinge.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/longer_context (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_Qwen3-8B_logistic.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/longer_context (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_gpt-oss-20b_diffmean.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/longer_context (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_gpt-oss-20b_hinge.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/longer_context (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_gpt-oss-20b_logistic.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/longer_context (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/longer_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_Llama-3.1-8B-Instruct_hinge.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/longer_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_Llama-3.1-8B-Instruct_logistic.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/longer_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/longer_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_Llama-3.3-70B-Instruct_hinge.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/longer_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_Llama-3.3-70B-Instruct_logistic.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/longer_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=971, num_layers=49
# Wrote AUROC record for SRAQ/longer_context (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_Qwen3-32B_diffmean.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/longer_context (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_Qwen3-32B_hinge.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/longer_context (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_Qwen3-32B_logistic.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/longer_context (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_Qwen3-8B_diffmean.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/longer_context (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_Qwen3-8B_hinge.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/longer_context (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_Qwen3-8B_logistic.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/longer_context (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_gpt-oss-20b_diffmean.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/longer_context (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_gpt-oss-20b_hinge.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/longer_context (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_SRAQ_longer_context_question_with_context_gpt-oss-20b_logistic.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/longer_context (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/paragraph (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_Llama-3.1-8B-Instruct_hinge.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/paragraph (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_Llama-3.1-8B-Instruct_logistic.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/paragraph (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/paragraph (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_Llama-3.3-70B-Instruct_hinge.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/paragraph (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_Llama-3.3-70B-Instruct_logistic.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/paragraph (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=971, num_layers=49
# Wrote AUROC record for SRAQ/paragraph (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_Qwen3-32B_diffmean.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/paragraph (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_Qwen3-32B_hinge.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/paragraph (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_Qwen3-32B_logistic.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/paragraph (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_Qwen3-8B_diffmean.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/paragraph (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_Qwen3-8B_hinge.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/paragraph (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_Qwen3-8B_logistic.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/paragraph (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_gpt-oss-20b_diffmean.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/paragraph (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_gpt-oss-20b_hinge.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/paragraph (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_gpt-oss-20b_logistic.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/paragraph (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/paragraph (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_Llama-3.1-8B-Instruct_hinge.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/paragraph (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_Llama-3.1-8B-Instruct_logistic.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/paragraph (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/paragraph (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_Llama-3.3-70B-Instruct_hinge.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/paragraph (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_Llama-3.3-70B-Instruct_logistic.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/paragraph (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=971, num_layers=49
# Wrote AUROC record for SRAQ/paragraph (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_Qwen3-32B_diffmean.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/paragraph (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_Qwen3-32B_hinge.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/paragraph (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_Qwen3-32B_logistic.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/paragraph (Qwen3-32B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_Qwen3-8B_diffmean.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/paragraph (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_Qwen3-8B_hinge.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/paragraph (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_Qwen3-8B_logistic.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/paragraph (Qwen3-8B)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_gpt-oss-20b_diffmean.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/paragraph (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_gpt-oss-20b_hinge.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/paragraph (gpt-oss-20b)
#
# === Processing projection_within_real/RQ_TO_SRAQ_paragraph_question_with_context_gpt-oss-20b_logistic.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/paragraph (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_full_turn_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_full_turn_Llama-3.1-8B-Instruct_hinge.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_full_turn_Llama-3.1-8B-Instruct_logistic.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_full_turn_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_full_turn_Llama-3.3-70B-Instruct_hinge.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_full_turn_Llama-3.3-70B-Instruct_logistic.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_full_turn_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=4997, num_layers=49
# Wrote AUROC record for RQ/question (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_full_turn_Qwen3-32B_diffmean.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_full_turn_Qwen3-32B_hinge.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_full_turn_Qwen3-32B_logistic.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_full_turn_Qwen3-8B_diffmean.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_full_turn_Qwen3-8B_hinge.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_full_turn_Qwen3-8B_logistic.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_full_turn_gpt-oss-20b_diffmean.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_full_turn_gpt-oss-20b_hinge.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_full_turn_gpt-oss-20b_logistic.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_longer_context_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_longer_context_Llama-3.1-8B-Instruct_hinge.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_longer_context_Llama-3.1-8B-Instruct_logistic.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_longer_context_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_longer_context_Llama-3.3-70B-Instruct_hinge.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_longer_context_Llama-3.3-70B-Instruct_logistic.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_longer_context_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=4997, num_layers=49
# Wrote AUROC record for RQ/question (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_longer_context_Qwen3-32B_diffmean.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_longer_context_Qwen3-32B_hinge.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_longer_context_Qwen3-32B_logistic.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_longer_context_Qwen3-8B_diffmean.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_longer_context_Qwen3-8B_hinge.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_longer_context_Qwen3-8B_logistic.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_longer_context_gpt-oss-20b_diffmean.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_longer_context_gpt-oss-20b_hinge.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_longer_context_gpt-oss-20b_logistic.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_paragraph_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_paragraph_Llama-3.1-8B-Instruct_hinge.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_paragraph_Llama-3.1-8B-Instruct_logistic.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_paragraph_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_paragraph_Llama-3.3-70B-Instruct_hinge.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_paragraph_Llama-3.3-70B-Instruct_logistic.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_paragraph_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=4997, num_layers=49
# Wrote AUROC record for RQ/question (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_paragraph_Qwen3-32B_diffmean.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_paragraph_Qwen3-32B_hinge.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_paragraph_Qwen3-32B_logistic.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_paragraph_Qwen3-8B_diffmean.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_paragraph_Qwen3-8B_hinge.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_paragraph_Qwen3-8B_logistic.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_paragraph_gpt-oss-20b_diffmean.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_paragraph_gpt-oss-20b_hinge.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_paragraph_gpt-oss-20b_logistic.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question_with_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_Llama-3.1-8B-Instruct_hinge.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question_with_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_Llama-3.1-8B-Instruct_logistic.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question_with_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question_with_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_Llama-3.3-70B-Instruct_hinge.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question_with_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_Llama-3.3-70B-Instruct_logistic.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question_with_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=4997, num_layers=49
# Wrote AUROC record for RQ/question_with_context (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_Qwen3-32B_diffmean.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question_with_context (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_Qwen3-32B_hinge.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question_with_context (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_Qwen3-32B_logistic.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question_with_context (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_Qwen3-8B_diffmean.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question_with_context (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_Qwen3-8B_hinge.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question_with_context (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_Qwen3-8B_logistic.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question_with_context (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_gpt-oss-20b_diffmean.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question_with_context (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_gpt-oss-20b_hinge.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question_with_context (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_full_turn_gpt-oss-20b_logistic.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question_with_context (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question_with_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_Llama-3.1-8B-Instruct_hinge.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question_with_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_Llama-3.1-8B-Instruct_logistic.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question_with_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question_with_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_Llama-3.3-70B-Instruct_hinge.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question_with_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_Llama-3.3-70B-Instruct_logistic.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question_with_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=4997, num_layers=49
# Wrote AUROC record for RQ/question_with_context (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_Qwen3-32B_diffmean.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question_with_context (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_Qwen3-32B_hinge.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question_with_context (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_Qwen3-32B_logistic.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question_with_context (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_Qwen3-8B_diffmean.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question_with_context (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_Qwen3-8B_hinge.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question_with_context (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_Qwen3-8B_logistic.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question_with_context (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_gpt-oss-20b_diffmean.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question_with_context (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_gpt-oss-20b_hinge.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question_with_context (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_longer_context_gpt-oss-20b_logistic.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question_with_context (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question_with_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_Llama-3.1-8B-Instruct_hinge.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question_with_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_Llama-3.1-8B-Instruct_logistic.pt ===
# N=4997, num_layers=33
# Wrote AUROC record for RQ/question_with_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question_with_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_Llama-3.3-70B-Instruct_hinge.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question_with_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_Llama-3.3-70B-Instruct_logistic.pt ===
# N=4997, num_layers=81
# Wrote AUROC record for RQ/question_with_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=4997, num_layers=49
# Wrote AUROC record for RQ/question_with_context (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_Qwen3-32B_diffmean.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question_with_context (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_Qwen3-32B_hinge.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question_with_context (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_Qwen3-32B_logistic.pt ===
# N=4997, num_layers=65
# Wrote AUROC record for RQ/question_with_context (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_Qwen3-8B_diffmean.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question_with_context (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_Qwen3-8B_hinge.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question_with_context (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_Qwen3-8B_logistic.pt ===
# N=4997, num_layers=37
# Wrote AUROC record for RQ/question_with_context (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_gpt-oss-20b_diffmean.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question_with_context (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_gpt-oss-20b_hinge.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question_with_context (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_RQ_question_with_context_paragraph_gpt-oss-20b_logistic.pt ===
# N=4997, num_layers=25
# Wrote AUROC record for RQ/question_with_context (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/full_turn (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_Llama-3.1-8B-Instruct_hinge.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/full_turn (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_Llama-3.1-8B-Instruct_logistic.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/full_turn (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/full_turn (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_Llama-3.3-70B-Instruct_hinge.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/full_turn (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_Llama-3.3-70B-Instruct_logistic.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/full_turn (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=971, num_layers=49
# Wrote AUROC record for SRAQ/full_turn (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_Qwen3-32B_diffmean.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/full_turn (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_Qwen3-32B_hinge.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/full_turn (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_Qwen3-32B_logistic.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/full_turn (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_Qwen3-8B_diffmean.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/full_turn (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_Qwen3-8B_hinge.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/full_turn (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_Qwen3-8B_logistic.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/full_turn (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_gpt-oss-20b_diffmean.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/full_turn (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_gpt-oss-20b_hinge.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/full_turn (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_longer_context_gpt-oss-20b_logistic.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/full_turn (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/full_turn (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_Llama-3.1-8B-Instruct_hinge.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/full_turn (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_Llama-3.1-8B-Instruct_logistic.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/full_turn (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/full_turn (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_Llama-3.3-70B-Instruct_hinge.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/full_turn (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_Llama-3.3-70B-Instruct_logistic.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/full_turn (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=971, num_layers=49
# Wrote AUROC record for SRAQ/full_turn (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_Qwen3-32B_diffmean.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/full_turn (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_Qwen3-32B_hinge.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/full_turn (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_Qwen3-32B_logistic.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/full_turn (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_Qwen3-8B_diffmean.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/full_turn (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_Qwen3-8B_hinge.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/full_turn (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_Qwen3-8B_logistic.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/full_turn (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_gpt-oss-20b_diffmean.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/full_turn (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_gpt-oss-20b_hinge.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/full_turn (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_full_turn_paragraph_gpt-oss-20b_logistic.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/full_turn (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/longer_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_Llama-3.1-8B-Instruct_hinge.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/longer_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_Llama-3.1-8B-Instruct_logistic.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/longer_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/longer_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_Llama-3.3-70B-Instruct_hinge.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/longer_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_Llama-3.3-70B-Instruct_logistic.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/longer_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=971, num_layers=49
# Wrote AUROC record for SRAQ/longer_context (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_Qwen3-32B_diffmean.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/longer_context (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_Qwen3-32B_hinge.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/longer_context (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_Qwen3-32B_logistic.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/longer_context (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_Qwen3-8B_diffmean.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/longer_context (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_Qwen3-8B_hinge.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/longer_context (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_Qwen3-8B_logistic.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/longer_context (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_gpt-oss-20b_diffmean.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/longer_context (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_gpt-oss-20b_hinge.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/longer_context (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_full_turn_gpt-oss-20b_logistic.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/longer_context (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/longer_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_Llama-3.1-8B-Instruct_hinge.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/longer_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_Llama-3.1-8B-Instruct_logistic.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/longer_context (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/longer_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_Llama-3.3-70B-Instruct_hinge.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/longer_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_Llama-3.3-70B-Instruct_logistic.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/longer_context (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=971, num_layers=49
# Wrote AUROC record for SRAQ/longer_context (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_Qwen3-32B_diffmean.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/longer_context (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_Qwen3-32B_hinge.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/longer_context (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_Qwen3-32B_logistic.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/longer_context (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_Qwen3-8B_diffmean.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/longer_context (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_Qwen3-8B_hinge.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/longer_context (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_Qwen3-8B_logistic.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/longer_context (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_gpt-oss-20b_diffmean.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/longer_context (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_gpt-oss-20b_hinge.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/longer_context (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_longer_context_paragraph_gpt-oss-20b_logistic.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/longer_context (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/paragraph (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_Llama-3.1-8B-Instruct_hinge.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/paragraph (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_Llama-3.1-8B-Instruct_logistic.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/paragraph (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/paragraph (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_Llama-3.3-70B-Instruct_hinge.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/paragraph (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_Llama-3.3-70B-Instruct_logistic.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/paragraph (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=971, num_layers=49
# Wrote AUROC record for SRAQ/paragraph (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_Qwen3-32B_diffmean.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/paragraph (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_Qwen3-32B_hinge.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/paragraph (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_Qwen3-32B_logistic.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/paragraph (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_Qwen3-8B_diffmean.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/paragraph (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_Qwen3-8B_hinge.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/paragraph (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_Qwen3-8B_logistic.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/paragraph (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_gpt-oss-20b_diffmean.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/paragraph (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_gpt-oss-20b_hinge.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/paragraph (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_full_turn_gpt-oss-20b_logistic.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/paragraph (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_Llama-3.1-8B-Instruct_diffmean.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/paragraph (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_Llama-3.1-8B-Instruct_hinge.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/paragraph (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_Llama-3.1-8B-Instruct_logistic.pt ===
# N=971, num_layers=33
# Wrote AUROC record for SRAQ/paragraph (Llama-3.1-8B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_Llama-3.3-70B-Instruct_diffmean.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/paragraph (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_Llama-3.3-70B-Instruct_hinge.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/paragraph (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_Llama-3.3-70B-Instruct_logistic.pt ===
# N=971, num_layers=81
# Wrote AUROC record for SRAQ/paragraph (Llama-3.3-70B-Instruct)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_Qwen3-30B-A3B-Instruct-2507_diffmean.pt ===
# N=971, num_layers=49
# Wrote AUROC record for SRAQ/paragraph (Qwen3-30B-A3B-Instruct-2507)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_Qwen3-32B_diffmean.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/paragraph (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_Qwen3-32B_hinge.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/paragraph (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_Qwen3-32B_logistic.pt ===
# N=971, num_layers=65
# Wrote AUROC record for SRAQ/paragraph (Qwen3-32B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_Qwen3-8B_diffmean.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/paragraph (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_Qwen3-8B_hinge.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/paragraph (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_Qwen3-8B_logistic.pt ===
# N=971, num_layers=37
# Wrote AUROC record for SRAQ/paragraph (Qwen3-8B)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_gpt-oss-20b_diffmean.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/paragraph (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_gpt-oss-20b_hinge.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/paragraph (gpt-oss-20b)
#
# === Processing projection_within_real/SRAQ_TO_SRAQ_paragraph_longer_context_gpt-oss-20b_logistic.pt ===
# N=971, num_layers=25
# Wrote AUROC record for SRAQ/paragraph (gpt-oss-20b)
#
# All done. AUROCs saved to auroc_project_within_real.jsonl
